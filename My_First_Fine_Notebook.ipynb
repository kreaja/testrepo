# %% [markdown]
# <a href="https://colab.research.google.com/github/kreaja/testrepo/blob/master/My_First_Fine_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# June 24th, 2022

# Now that I know how to mount Google Drive and use files that are stored there,
# I'll be able to run machine learning experiments using Google's resources.

# Work can be saved to Google Drive or even my GitHub repository
# Out:
# Archive:  BreCaHAD.zip
#   inflating: ./BreCaHAD images/LICENSE
#   inflating: ./BreCaHAD images/README.md
#    creating: ./BreCaHAD images/images/
#   inflating: ./BreCaHAD images/images/Case_1-01.tif
#   inflating: ./BreCaHAD images/images/Case_1-02.tif
#   inflating: ./BreCaHAD images/images/Case_1-03.tif
#   inflating: ./BreCaHAD images/images/Case_1-04.tif
#   inflating: ./BreCaHAD images/images/Case_1-05.tif
#   inflating: ./BreCaHAD images/images/Case_1-06.tif
#   inflating: ./BreCaHAD images/images/Case_1-07.tif
#   inflating: ./BreCaHAD images/images/Case_1-08.tif
#   inflating: ./BreCaHAD images/images/Case_10-01.tif
#   inflating: ./BreCaHAD images/images/Case_10-02.tif
#   inflating: ./BreCaHAD images/images/Case_10-03.tif
#   inflating: ./BreCaHAD images/images/Case_10-04.tif
#   inflating: ./BreCaHAD images/images/Case_10-05.tif
#   inflating: ./BreCaHAD images/images/Case_10-06.tif
#   inflating: ./BreCaHAD images/images/Case_10-07.tif
# ...
